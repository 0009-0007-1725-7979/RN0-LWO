# %% [markdown]
# This Jupyter Notebook includes code adapted from the RouteNet project.
#
# Original author:
#
# Krzysztof Rusek AGH University of Science and Technology, Department of Communications, Krakow, Poland. Email: krusek@agh.edu.pl This code is licensed under the BSD 3-Clause License. See the LICENSE file in this repository for details.

# %%
import tensorflow as tf

from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False

from tensorflow import keras

import tensorflow_addons as tfa

import numpy as np
from dataclasses import dataclass, field
from typing import Optional
import glob

# %%
print(tf.__version__)
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2.15.0
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
def parse(serialized, target='delay'): #Target is the name of predicted variable
    
    with tf.name_scope('parse'):    
        features = tf.compat.v1.parse_single_example(
            serialized,
            features={
                'traffic':tf.compat.v1.VarLenFeature(tf.float32),
                target:tf.compat.v1.VarLenFeature(tf.float32),
                'links':tf.compat.v1.VarLenFeature(tf.int64),
                'paths':tf.compat.v1.VarLenFeature(tf.int64),
                'sequances':tf.compat.v1.VarLenFeature(tf.int64),
                'n_links':tf.compat.v1.FixedLenFeature([],tf.int64), 
                'n_paths':tf.compat.v1.FixedLenFeature([],tf.int64),
                'n_total':tf.compat.v1.FixedLenFeature([],tf.int64)
            }
        )
        
        for k in ['traffic',target,'links','paths','sequances']:
            features[k] = tf.compat.v1.sparse_tensor_to_dense(features[k])
            if k == 'delay':
                features[k] = (features[k]-2.8)/2.5
                
            if k == 'traffic':
                #features[k] = (features[k]-0.76)/.008
                features[k] = (features[k]-0.5)/.5
                
            # if k == 'drops':
            #     features[k] = (features[k])/12000/(0.5*features['traffic']+0.5) #loss rate
            #if k == 'jitter':
                #features[k] = (tf.math.log( features[k] )-2.0)/2.0 #logjitter
            
    return {k:v for k,v in features.items() if k is not target },features[target]

# %%
def tfrecord_input_fn(filenames,hparams,shuffle_buf=1000, target='delay'):
    
    files = tf.data.Dataset.from_tensor_slices(filenames)
    files = files.shuffle(len(filenames))

    ds = files.interleave(tf.data.TFRecordDataset, cycle_length=4)

    if shuffle_buf:
        ds = ds.shuffle(shuffle_buf).repeat()
    
    # ds = ds.map(lambda buf:parse(buf,target), num_parallel_calls=2)
    ds = ds.map(lambda buf:parse(buf,target), num_parallel_calls=tf.data.AUTOTUNE)

    shapes=(
        {
        'traffic':[hparams.node_count*(hparams.node_count-1)],
        'links':[-1],
        'paths':[-1],
        'sequances':[-1],
        'n_links':[],
        'n_paths':[],
        'n_total':[]
        },
        [hparams.node_count*(hparams.node_count-1)]
    )
    
    ds = ds.padded_batch(hparams.batch_size,shapes)
    ds = ds.prefetch(1)
    
    return ds

# %%
class ComnetModel(tf.keras.Model):
    def __init__(self,hparams, output_units=1):
        super(ComnetModel, self).__init__()
        self.hparams = hparams

        self.edge_update = tf.compat.v1.nn.rnn_cell.GRUCell(hparams.link_state_dim, dtype=tf.float32)
        self.path_update = tf.compat.v1.nn.rnn_cell.GRUCell(hparams.path_state_dim, dtype=tf.float32)
        # self.edge_update = tf.keras.layers.GRUCell(hparams.link_state_dim)
        # self.path_update = tf.keras.layers.GRUCell(hparams.path_state_dim)
        
        self.readout = tf.keras.models.Sequential()
        
        self.readout.add(keras.layers.Dense(hparams.readout_units, activation=tf.nn.selu, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
        self.readout.add(keras.layers.Dropout(rate=hparams.dropout_rate))
        
        self.readout.add(keras.layers.Dense(hparams.readout_units, activation=tf.nn.selu, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
        self.readout.add(keras.layers.Dropout(rate=hparams.dropout_rate))
        
        self.readout.add(keras.layers.Dense(output_units, kernel_regularizer=tf.keras.regularizers.l2(hparams.l2)))
            
    def build(self, input_shape=None):
        del input_shape
        self.edge_update.build(tf.TensorShape([None,self.hparams.path_state_dim]))
        self.path_update.build(tf.TensorShape([None,self.hparams.link_state_dim]))
        self.readout.build(input_shape = [None,self.hparams.path_state_dim])
        self.built = True

    def call(self, inputs, training=False):
        f_ = inputs
        shape = tf.stack([f_['n_links'],self.hparams.link_state_dim], axis=0)
        link_state = tf.zeros(shape)
        shape = tf.stack([f_['n_paths'],self.hparams.path_state_dim-1], axis=0)
        path_state = tf.concat([tf.expand_dims(f_['traffic'],axis=1), tf.zeros(shape)], axis=1)

        links = f_['links'][0:f_["n_total"]]
        paths = f_['paths'][0:f_["n_total"]]
        seqs=  f_['sequances'][0:f_["n_total"]]
        
        for _ in range(self.hparams.T):
        
            h_tild = tf.gather(link_state,links)

            ids=tf.stack([paths, seqs], axis=1)            
            max_len = tf.reduce_max(seqs)+1
            shape = tf.stack([f_['n_paths'], max_len, self.hparams.link_state_dim])
            lens = tf.compat.v1.segment_sum(data=tf.ones_like(paths), segment_ids=paths)

            link_inputs = tf.scatter_nd(ids, h_tild, shape)
            outputs, path_state = tf.compat.v1.nn.dynamic_rnn(self.path_update,link_inputs,sequence_length=lens,initial_state=path_state,dtype=tf.float32)
            m = tf.gather_nd(outputs,ids)
            m = tf.compat.v1.unsorted_segment_sum(m, links ,f_['n_links'])
            _,link_state = self.edge_update(m, link_state)
        
        r = self.readout(path_state,training=training)
        
        return r

# %%
def streaming_pearson_correlation_dl(labels, predictions, weights=None):
    """
    Compute streaming Pearson correlation with distributed training compatibility.
    Handles both single-replica and multi-replica contexts.
    Returns (value_tensor, update_op) for use in eval_metric_ops.
    """
    global learning_strategy
    
    # Cast inputs to float32 for compatibility
    labels = tf.cast(labels, tf.float32)
    predictions = tf.cast(predictions, tf.float32)

    # Batch-wise computations
    batch_size = tf.cast(tf.size(labels), tf.float32)
    batch_mean_x = tf.reduce_mean(predictions)
    batch_mean_y = tf.reduce_mean(labels)
    batch_mean_x_squared = tf.reduce_mean(tf.square(predictions))
    batch_mean_y_squared = tf.reduce_mean(tf.square(labels))
    batch_mean_xy = tf.reduce_mean(predictions * labels)

    # Use tf.metrics to accumulate streaming values
    mean_x, update_mean_x = tf.compat.v1.metrics.mean(batch_mean_x, weights)
    mean_y, update_mean_y = tf.compat.v1.metrics.mean(batch_mean_y, weights)
    mean_x_squared, update_mean_x_squared = tf.compat.v1.metrics.mean(batch_mean_x_squared, weights)
    mean_y_squared, update_mean_y_squared = tf.compat.v1.metrics.mean(batch_mean_y_squared, weights)
    mean_xy, update_mean_xy = tf.compat.v1.metrics.mean(batch_mean_xy, weights)
    count, update_count = tf.compat.v1.metrics.mean(batch_size, weights)

    # Compute Pearson correlation
    def compute_correlation():
        covariance = mean_xy - mean_x * mean_y
        variance_x = mean_x_squared - tf.square(mean_x)
        variance_y = mean_y_squared - tf.square(mean_y)
        denominator = tf.sqrt(variance_x * variance_y)
        return tf.where(tf.greater(denominator, 0), covariance / denominator, 0.0)

    rho = compute_correlation()

    # Group all update ops
    update_op = tf.group(
        update_mean_x, update_mean_y, update_mean_x_squared,
        update_mean_y_squared, update_mean_xy, update_count
    )

    # Distributed training compatibility
    if learning_strategy and learning_strategy.num_replicas_in_sync > 1:
        
        # Aggregate distributed values using the strategy context
        def aggregate_rho(learning_strategy, rho):
            return learning_strategy.reduce(tf.distribute.ReduceOp.MEAN, rho, axis=None)

        # Use merge_call to enter cross-replica context
        rho = tf.distribute.get_replica_context().merge_call(lambda ctx: aggregate_rho(ctx, rho))

    return rho, update_op

# %%
def model_fn(features, labels, mode, params):
    
    model = ComnetModel(params)
    model.build()
    #model.summary()

    predictions = tf.map_fn(lambda x: model(x,training=mode==tf.estimator.ModeKeys.TRAIN), features,dtype=tf.float32)
    #predictions = model(features,training=mode==tf.estimator.ModeKeys.TRAIN)
    predictions = tf.squeeze(predictions)

    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions={'predictions':predictions})

    loss =  tf.compat.v1.losses.mean_squared_error(labels=labels, predictions = predictions, reduction=tf.compat.v1.losses.Reduction.MEAN)

    regularization_loss = sum(model.losses)
    total_loss = loss + regularization_loss

    if mode == tf.estimator.ModeKeys.EVAL:
        
        return tf.estimator.EstimatorSpec(
            mode,
            loss=loss,
            eval_metric_ops=
            {
                'mse': tf.compat.v1.metrics.mean_squared_error(labels=labels, predictions=predictions),
                #'rho_contrib':tf.contrib.metrics.streaming_pearson_correlation(labels=labels,predictions=predictions),
                'rho': streaming_pearson_correlation_dl(labels, predictions)
            }
        )
    
    assert mode == tf.estimator.ModeKeys.TRAIN

    # Get all trainable variables
    # trainables = model.variables
    trainables = tf.compat.v1.trainable_variables()
    
    grads = tf.gradients(total_loss, trainables)
    grad_var_pairs = zip(grads, trainables)

    # optimizer=tf.compat.v1.train.AdamOptimizer(params.learning_rate)
    optimizer = tfa.optimizers.LAMB(learning_rate=params.learning_rate, weight_decay=params.l2)
    
    update_ops = tf.compat.v1.get_collection(tf.compat.v1.GraphKeys.UPDATE_OPS)
    
    # with tf.control_dependencies(update_ops):
    #     train_op = optimizer.apply_gradients(grad_var_pairs, global_step=tf.compat.v1.train.get_global_step())

    global_step = tf.compat.v1.train.get_or_create_global_step()
    apply_op = optimizer.apply_gradients(grad_var_pairs)
    with tf.control_dependencies([apply_op]):
        train_op = tf.compat.v1.assign_add(global_step, 1)
        
    # Log weight and gradient norms
    for var in trainables:
        # Weight norm (parameter size)
        w_norm = tf.norm(var)
        tf.compat.v1.summary.scalar(f"weight_norm/{var.op.name}", w_norm)
     
        # Gradient norm (update strength)
        grad = tf.gradients(loss, var)[0]
        if grad is not None:
            g_norm = tf.norm(grad)
            tf.compat.v1.summary.scalar(f"grad_norm/{var.op.name}", g_norm)
        
    # epsilon for numerical stability
    eps = 1e-7

    # Build list of grad-to-weight ratio tensors
    ratios = []
    for var, g in zip(trainables, grads):
        if g is not None:
            grad_norm = tf.norm(tf.reshape(g, [-1]))
            weight_norm = tf.norm(tf.reshape(var, [-1]))
            ratio = grad_norm / (weight_norm + eps)
            ratios.append(ratio)
            # optional: keep per-layer scalar too
            tf.compat.v1.summary.scalar(f"grad_to_weight/{var.op.name}", ratio)

    # Only aggregate if we have any ratios
    if len(ratios) > 0:
        stacked = tf.stack(ratios)                      # shape: [num_layers]
        mean_ratio = tf.reduce_mean(stacked)
        std_ratio = tf.math.reduce_std(stacked)
        max_ratio = tf.reduce_max(stacked)
        min_ratio = tf.reduce_min(stacked)
        cv_ratio = tf.where(tf.greater(mean_ratio, 0.0), std_ratio / mean_ratio, 0.0)
 
    # Scalars
    tf.compat.v1.summary.scalar("training_loss", loss)
    tf.compat.v1.summary.scalar("regularization_loss", regularization_loss)
    tf.compat.v1.summary.scalar("agg/mean_grad_to_weight", mean_ratio)
    tf.compat.v1.summary.scalar("agg/std_grad_to_weight", std_ratio)
    tf.compat.v1.summary.scalar("agg/cv_grad_to_weight", cv_ratio)
    tf.compat.v1.summary.scalar("agg/max_grad_to_weight", max_ratio)
    tf.compat.v1.summary.scalar("agg/min_grad_to_weight", min_ratio)
    
    # Histograms (weights and gradients)
    hist_summaries = []
    for var in trainables:
        if isinstance(var, tf.Tensor):
            hist_summaries.append(tf.compat.v1.summary.histogram(var.op.name, var))
    for g in grads:
        if g is not None and isinstance(g, tf.Tensor):
            hist_summaries.append(tf.compat.v1.summary.histogram(g.op.name, g))
     
    # Merge summaries
    merged_summary = tf.compat.v1.summary.merge_all()
     
    # Hook
    summary_hook = tf.estimator.SummarySaverHook(save_steps=100, output_dir=log_dir, summary_op=merged_summary)

    hooks = []
    if mode == tf.estimator.ModeKeys.TRAIN:
        hooks = [summary_hook]
    
    return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op, training_hooks=hooks)

# %%
def train(args):
    
    print(args.hparams)
    tf.compat.v1.logging.set_verbosity('INFO')

    global learning_strategy, log_dir
    learning_strategy = args.strategy
    log_dir = args.model_dir

    my_checkpointing_config = tf.estimator.RunConfig(
        train_distribute=args.strategy,
        eval_distribute=args.strategy,
        save_checkpoints_steps=1000,
        keep_checkpoint_max=50
    )

    estimator = tf.estimator.Estimator(
        model_fn=model_fn, 
        model_dir=args.model_dir, 
        params=args.hparams, 
        warm_start_from=args.warm, 
        config=my_checkpointing_config)

    train_spec = tf.estimator.TrainSpec(input_fn=lambda:tfrecord_input_fn(args.train,args.hparams,shuffle_buf=args.shuffle_buf,target=args.target),max_steps=args.train_steps)
    eval_spec = tf.estimator.EvalSpec(input_fn=lambda:tfrecord_input_fn(args.eval_,args.hparams,shuffle_buf=None,target=args.target),steps=args.eval_steps,throttle_secs=1)

    tf.estimator.train_and_evaluate(estimator, train_spec, eval_spec)

# %%
# tfrecord_train_files = glob.glob("nsfnet/tfrecords/train/*.tfrecords")
# tfrecord_eval_files = glob.glob("nsfnet/tfrecords/evaluate/*.tfrecords")

tfrecord_train_files = glob.glob("gbn/tfrecords/train/*.tfrecords")
tfrecord_eval_files = glob.glob("gbn/tfrecords/evaluate/*.tfrecords")

@dataclass
class HyperParams:
    # node_count: int = 14
    node_count: int = 17
    link_state_dim: int = 16
    path_state_dim: int = 32
    T: int = 8
    readout_units: int = 256
    learning_rate: float = 0.001
    batch_size: int = 32
    dropout_rate: float = 0.5
    l2: float = 0.01

@dataclass
class Args:
    target: str = "delay"
    strategy: Optional[str] = tf.distribute.MirroredStrategy() #None
    hparams: HyperParams = HyperParams()
    train: list = field(default_factory=lambda: tfrecord_train_files)
    eval_: list = field(default_factory=lambda: tfrecord_eval_files)
    model_dir: str = "rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70"
    train_steps: int = 50000
    eval_steps: Optional[int] = None
    shuffle_buf: int = 30000
    warm: Optional[str] = None

args = Args()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')

# %%
# %time train(args)
# Out:
# HyperParams(node_count=17, link_state_dim=16, path_state_dim=32, T=8, readout_units=256, learning_rate=0.001, batch_size=32, dropout_rate=0.5, l2=0.01)
# INFO:tensorflow:Initializing RunConfig with distribution strategies.
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Using config: {'_model_dir': 'rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 1000, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 50, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': <tensorflow.python.distribute.mirrored_strategy.MirroredStrategy object at 0x1470277ab850>, '_device_fn': None, '_protocol': None, '_eval_distribute': <tensorflow.python.distribute.mirrored_strategy.MirroredStrategy object at 0x1470277ab850>, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1, '_distribute_coordinator_mode': None}
# INFO:tensorflow:Not using Distribute Coordinator.
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 1000 or save_checkpoints_secs None.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Collective all_reduce tensors: 14 all_reduces, num_devices = 2, group_size = 2, implementation = CommunicationImplementation.NCCL, num_packs = 1
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 2.0706677, step = 0
# INFO:tensorflow:global_step/sec: 1.26355
# INFO:tensorflow:loss = 0.36142153, step = 100 (79.144 sec)
# INFO:tensorflow:global_step/sec: 1.40202
# INFO:tensorflow:loss = 0.17823529, step = 200 (71.326 sec)
# INFO:tensorflow:global_step/sec: 1.41147
# INFO:tensorflow:loss = 0.13552505, step = 300 (70.848 sec)
# INFO:tensorflow:global_step/sec: 1.4104
# INFO:tensorflow:loss = 0.09764744, step = 400 (70.903 sec)
# INFO:tensorflow:global_step/sec: 1.41929
# INFO:tensorflow:loss = 0.078534395, step = 500 (70.456 sec)
# INFO:tensorflow:global_step/sec: 1.42434
# INFO:tensorflow:loss = 0.06329128, step = 600 (70.209 sec)
# INFO:tensorflow:global_step/sec: 1.41894
# INFO:tensorflow:loss = 0.057080567, step = 700 (70.475 sec)
# INFO:tensorflow:global_step/sec: 1.42582
# INFO:tensorflow:loss = 0.042258494, step = 800 (70.135 sec)
# INFO:tensorflow:global_step/sec: 1.408
# INFO:tensorflow:loss = 0.036047593, step = 900 (71.022 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /replica:0/task:0/device:CPU:0 then broadcast to ('/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T17:35:24
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 413.44156s
# INFO:tensorflow:Finished evaluation at 2025-10-26-17:42:18
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.009393895, mse = 0.009393843, rho = 0.9612893
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 0.203565
# INFO:tensorflow:loss = 0.032234628, step = 1000 (491.244 sec)
# INFO:tensorflow:global_step/sec: 1.42699
# INFO:tensorflow:loss = 0.025007315, step = 1100 (70.079 sec)
# INFO:tensorflow:global_step/sec: 1.41683
# INFO:tensorflow:loss = 0.020669075, step = 1200 (70.579 sec)
# INFO:tensorflow:global_step/sec: 1.41501
# INFO:tensorflow:loss = 0.022135695, step = 1300 (70.671 sec)
# INFO:tensorflow:global_step/sec: 1.42349
# INFO:tensorflow:loss = 0.017017268, step = 1400 (70.249 sec)
# INFO:tensorflow:global_step/sec: 1.41935
# INFO:tensorflow:loss = 0.018346824, step = 1500 (70.455 sec)
# INFO:tensorflow:global_step/sec: 1.43435
# INFO:tensorflow:loss = 0.017963193, step = 1600 (69.719 sec)
# INFO:tensorflow:global_step/sec: 1.43431
# INFO:tensorflow:loss = 0.014437634, step = 1700 (69.719 sec)
# INFO:tensorflow:global_step/sec: 1.43701
# INFO:tensorflow:loss = 0.013200093, step = 1800 (69.590 sec)
# INFO:tensorflow:global_step/sec: 1.42934
# INFO:tensorflow:loss = 0.01614072, step = 1900 (69.962 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 2000...
# INFO:tensorflow:Saving checkpoints for 2000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 2000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T17:54:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 413.67847s
# INFO:tensorflow:Finished evaluation at 2025-10-26-18:01:01
# INFO:tensorflow:Saving dict for global step 2000: global_step = 2000, loss = 0.002569285, mse = 0.0025692405, rho = 0.988614
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 0.203717
# INFO:tensorflow:loss = 0.014967186, step = 2000 (490.875 sec)
# INFO:tensorflow:global_step/sec: 1.42006
# INFO:tensorflow:loss = 0.013643296, step = 2100 (70.420 sec)
# INFO:tensorflow:global_step/sec: 1.41987
# INFO:tensorflow:loss = 0.01172516, step = 2200 (70.429 sec)
# INFO:tensorflow:global_step/sec: 1.41826
# INFO:tensorflow:loss = 0.013881868, step = 2300 (70.509 sec)
# INFO:tensorflow:global_step/sec: 1.42905
# INFO:tensorflow:loss = 0.012999054, step = 2400 (69.977 sec)
# INFO:tensorflow:global_step/sec: 1.42074
# INFO:tensorflow:loss = 0.012041983, step = 2500 (70.386 sec)
# INFO:tensorflow:global_step/sec: 1.42314
# INFO:tensorflow:loss = 0.0118245175, step = 2600 (70.268 sec)
# INFO:tensorflow:global_step/sec: 1.41948
# INFO:tensorflow:loss = 0.011758063, step = 2700 (70.448 sec)
# INFO:tensorflow:global_step/sec: 1.42792
# INFO:tensorflow:loss = 0.0101725925, step = 2800 (70.033 sec)
# INFO:tensorflow:global_step/sec: 1.42554
# INFO:tensorflow:loss = 0.011622971, step = 2900 (70.148 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 3000...
# INFO:tensorflow:Saving checkpoints for 3000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 3000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T18:12:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-3000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.85784s
# INFO:tensorflow:Finished evaluation at 2025-10-26-18:19:43
# INFO:tensorflow:Saving dict for global step 3000: global_step = 3000, loss = 0.0008163586, mse = 0.0008163594, rho = 0.99552214
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 3000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-3000
# INFO:tensorflow:global_step/sec: 0.203874
# INFO:tensorflow:loss = 0.010922636, step = 3000 (490.499 sec)
# INFO:tensorflow:global_step/sec: 1.41271
# INFO:tensorflow:loss = 0.01144609, step = 3100 (70.786 sec)
# INFO:tensorflow:global_step/sec: 1.42191
# INFO:tensorflow:loss = 0.009591297, step = 3200 (70.327 sec)
# INFO:tensorflow:global_step/sec: 1.42458
# INFO:tensorflow:loss = 0.009029024, step = 3300 (70.196 sec)
# INFO:tensorflow:global_step/sec: 1.43136
# INFO:tensorflow:loss = 0.009127835, step = 3400 (69.865 sec)
# INFO:tensorflow:global_step/sec: 1.43624
# INFO:tensorflow:loss = 0.0088109, step = 3500 (69.624 sec)
# INFO:tensorflow:global_step/sec: 1.43691
# INFO:tensorflow:loss = 0.011095055, step = 3600 (69.593 sec)
# INFO:tensorflow:global_step/sec: 1.43822
# INFO:tensorflow:loss = 0.010081653, step = 3700 (69.530 sec)
# INFO:tensorflow:global_step/sec: 1.44122
# INFO:tensorflow:loss = 0.009432605, step = 3800 (69.386 sec)
# INFO:tensorflow:global_step/sec: 1.44288
# INFO:tensorflow:loss = 0.0086999135, step = 3900 (69.305 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 4000...
# INFO:tensorflow:Saving checkpoints for 4000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 4000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T18:31:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-4000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.39639s
# INFO:tensorflow:Finished evaluation at 2025-10-26-18:38:21
# INFO:tensorflow:Saving dict for global step 4000: global_step = 4000, loss = 0.0013060737, mse = 0.0013060453, rho = 0.9949836
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 4000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-4000
# INFO:tensorflow:global_step/sec: 0.204553
# INFO:tensorflow:loss = 0.009655764, step = 4000 (488.870 sec)
# INFO:tensorflow:global_step/sec: 1.42685
# INFO:tensorflow:loss = 0.007861761, step = 4100 (70.084 sec)
# INFO:tensorflow:global_step/sec: 1.41598
# INFO:tensorflow:loss = 0.009870833, step = 4200 (70.623 sec)
# INFO:tensorflow:global_step/sec: 1.43153
# INFO:tensorflow:loss = 0.009557859, step = 4300 (69.855 sec)
# INFO:tensorflow:global_step/sec: 1.41829
# INFO:tensorflow:loss = 0.008263397, step = 4400 (70.507 sec)
# INFO:tensorflow:global_step/sec: 1.40525
# INFO:tensorflow:loss = 0.009170781, step = 4500 (71.162 sec)
# INFO:tensorflow:global_step/sec: 1.42514
# INFO:tensorflow:loss = 0.008583693, step = 4600 (70.169 sec)
# INFO:tensorflow:global_step/sec: 1.42504
# INFO:tensorflow:loss = 0.009456362, step = 4700 (70.173 sec)
# INFO:tensorflow:global_step/sec: 1.42365
# INFO:tensorflow:loss = 0.009073481, step = 4800 (70.243 sec)
# INFO:tensorflow:global_step/sec: 1.41533
# INFO:tensorflow:loss = 0.0095715085, step = 4900 (70.654 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 5000...
# INFO:tensorflow:Saving checkpoints for 5000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 5000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T18:50:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-5000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.52037s
# INFO:tensorflow:Finished evaluation at 2025-10-26-18:57:04
# INFO:tensorflow:Saving dict for global step 5000: global_step = 5000, loss = 0.0012909197, mse = 0.0012909332, rho = 0.9943001
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 5000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-5000
# INFO:tensorflow:global_step/sec: 0.204189
# INFO:tensorflow:loss = 0.008018523, step = 5000 (489.743 sec)
# INFO:tensorflow:global_step/sec: 1.41845
# INFO:tensorflow:loss = 0.0073372647, step = 5100 (70.539 sec)
# INFO:tensorflow:global_step/sec: 1.42036
# INFO:tensorflow:loss = 0.0128631815, step = 5200 (70.365 sec)
# INFO:tensorflow:global_step/sec: 1.42686
# INFO:tensorflow:loss = 0.007371053, step = 5300 (70.084 sec)
# INFO:tensorflow:global_step/sec: 1.4155
# INFO:tensorflow:loss = 0.010310067, step = 5400 (70.647 sec)
# INFO:tensorflow:global_step/sec: 1.42192
# INFO:tensorflow:loss = 0.010541784, step = 5500 (70.327 sec)
# INFO:tensorflow:global_step/sec: 1.43054
# INFO:tensorflow:loss = 0.0072929016, step = 5600 (69.904 sec)
# INFO:tensorflow:global_step/sec: 1.43434
# INFO:tensorflow:loss = 0.007969087, step = 5700 (69.720 sec)
# INFO:tensorflow:global_step/sec: 1.43454
# INFO:tensorflow:loss = 0.008228564, step = 5800 (69.707 sec)
# INFO:tensorflow:global_step/sec: 1.43388
# INFO:tensorflow:loss = 0.007360057, step = 5900 (69.741 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 6000...
# INFO:tensorflow:Saving checkpoints for 6000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 6000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T19:08:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-6000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 413.42226s
# INFO:tensorflow:Finished evaluation at 2025-10-26-19:15:45
# INFO:tensorflow:Saving dict for global step 6000: global_step = 6000, loss = 0.0005977887, mse = 0.0005977913, rho = 0.99804425
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 6000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-6000
# INFO:tensorflow:global_step/sec: 0.20422
# INFO:tensorflow:loss = 0.007636783, step = 6000 (489.669 sec)
# INFO:tensorflow:global_step/sec: 1.40886
# INFO:tensorflow:loss = 0.007654313, step = 6100 (70.980 sec)
# INFO:tensorflow:global_step/sec: 1.42059
# INFO:tensorflow:loss = 0.00905212, step = 6200 (70.393 sec)
# INFO:tensorflow:global_step/sec: 1.42807
# INFO:tensorflow:loss = 0.0064472435, step = 6300 (70.025 sec)
# INFO:tensorflow:global_step/sec: 1.42763
# INFO:tensorflow:loss = 0.0057991873, step = 6400 (70.046 sec)
# INFO:tensorflow:global_step/sec: 1.43875
# INFO:tensorflow:loss = 0.0078121535, step = 6500 (69.504 sec)
# INFO:tensorflow:global_step/sec: 1.44519
# INFO:tensorflow:loss = 0.0059927525, step = 6600 (69.195 sec)
# INFO:tensorflow:global_step/sec: 1.42763
# INFO:tensorflow:loss = 0.006568659, step = 6700 (70.046 sec)
# INFO:tensorflow:global_step/sec: 1.43187
# INFO:tensorflow:loss = 0.005973258, step = 6800 (69.839 sec)
# INFO:tensorflow:global_step/sec: 1.44421
# INFO:tensorflow:loss = 0.0065621687, step = 6900 (69.241 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 7000...
# INFO:tensorflow:Saving checkpoints for 7000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 7000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T19:27:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-7000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.93629s
# INFO:tensorflow:Finished evaluation at 2025-10-26-19:34:24
# INFO:tensorflow:Saving dict for global step 7000: global_step = 7000, loss = 0.001014092, mse = 0.001014101, rho = 0.99716425
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 7000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-7000
# INFO:tensorflow:global_step/sec: 0.204311
# INFO:tensorflow:loss = 0.0071324753, step = 7000 (489.450 sec)
# INFO:tensorflow:global_step/sec: 1.4304
# INFO:tensorflow:loss = 0.0066827754, step = 7100 (69.910 sec)
# INFO:tensorflow:global_step/sec: 1.427
# INFO:tensorflow:loss = 0.0062435423, step = 7200 (70.077 sec)
# INFO:tensorflow:global_step/sec: 1.42271
# INFO:tensorflow:loss = 0.008072613, step = 7300 (70.288 sec)
# INFO:tensorflow:global_step/sec: 1.42754
# INFO:tensorflow:loss = 0.010209007, step = 7400 (70.051 sec)
# INFO:tensorflow:global_step/sec: 1.4322
# INFO:tensorflow:loss = 0.0054389164, step = 7500 (69.822 sec)
# INFO:tensorflow:global_step/sec: 1.4192
# INFO:tensorflow:loss = 0.008569775, step = 7600 (70.462 sec)
# INFO:tensorflow:global_step/sec: 1.43502
# INFO:tensorflow:loss = 0.006410684, step = 7700 (69.686 sec)
# INFO:tensorflow:global_step/sec: 1.42961
# INFO:tensorflow:loss = 0.0075432505, step = 7800 (69.949 sec)
# INFO:tensorflow:global_step/sec: 1.42781
# INFO:tensorflow:loss = 0.005944915, step = 7900 (70.037 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 8000...
# INFO:tensorflow:Saving checkpoints for 8000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 8000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T19:46:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-8000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 411.90613s
# INFO:tensorflow:Finished evaluation at 2025-10-26-19:53:05
# INFO:tensorflow:Saving dict for global step 8000: global_step = 8000, loss = 0.00047777084, mse = 0.00047777337, rho = 0.9981746
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 8000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-8000
# INFO:tensorflow:global_step/sec: 0.203677
# INFO:tensorflow:loss = 0.0063013546, step = 8000 (490.973 sec)
# INFO:tensorflow:global_step/sec: 1.43575
# INFO:tensorflow:loss = 0.0064073447, step = 8100 (69.650 sec)
# INFO:tensorflow:global_step/sec: 1.42914
# INFO:tensorflow:loss = 0.005620718, step = 8200 (69.973 sec)
# INFO:tensorflow:global_step/sec: 1.41587
# INFO:tensorflow:loss = 0.007410241, step = 8300 (70.628 sec)
# INFO:tensorflow:global_step/sec: 1.41362
# INFO:tensorflow:loss = 0.005860473, step = 8400 (70.741 sec)
# INFO:tensorflow:global_step/sec: 1.41966
# INFO:tensorflow:loss = 0.0063455706, step = 8500 (70.439 sec)
# INFO:tensorflow:global_step/sec: 1.42269
# INFO:tensorflow:loss = 0.0055485372, step = 8600 (70.289 sec)
# INFO:tensorflow:global_step/sec: 1.42032
# INFO:tensorflow:loss = 0.0066950303, step = 8700 (70.407 sec)
# INFO:tensorflow:global_step/sec: 1.43201
# INFO:tensorflow:loss = 0.0063821324, step = 8800 (69.832 sec)
# INFO:tensorflow:global_step/sec: 1.43077
# INFO:tensorflow:loss = 0.005933812, step = 8900 (69.893 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 9000...
# INFO:tensorflow:Saving checkpoints for 9000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 9000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T20:04:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-9000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 411.70821s
# INFO:tensorflow:Finished evaluation at 2025-10-26-20:11:45
# INFO:tensorflow:Saving dict for global step 9000: global_step = 9000, loss = 0.00022078013, mse = 0.0002207822, rho = 0.99908435
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 9000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-9000
# INFO:tensorflow:global_step/sec: 0.204828
# INFO:tensorflow:loss = 0.005268895, step = 9000 (488.215 sec)
# INFO:tensorflow:global_step/sec: 1.4286
# INFO:tensorflow:loss = 0.006240925, step = 9100 (69.999 sec)
# INFO:tensorflow:global_step/sec: 1.42653
# INFO:tensorflow:loss = 0.005065607, step = 9200 (70.101 sec)
# INFO:tensorflow:global_step/sec: 1.42077
# INFO:tensorflow:loss = 0.0065658167, step = 9300 (70.384 sec)
# INFO:tensorflow:global_step/sec: 1.42602
# INFO:tensorflow:loss = 0.008283747, step = 9400 (70.126 sec)
# INFO:tensorflow:global_step/sec: 1.43713
# INFO:tensorflow:loss = 0.006679577, step = 9500 (69.582 sec)
# INFO:tensorflow:global_step/sec: 1.41453
# INFO:tensorflow:loss = 0.0062604127, step = 9600 (70.695 sec)
# INFO:tensorflow:global_step/sec: 1.42215
# INFO:tensorflow:loss = 0.0066927257, step = 9700 (70.316 sec)
# INFO:tensorflow:global_step/sec: 1.40998
# INFO:tensorflow:loss = 0.0063499887, step = 9800 (70.922 sec)
# INFO:tensorflow:global_step/sec: 1.42105
# INFO:tensorflow:loss = 0.0049119266, step = 9900 (70.371 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 10000...
# INFO:tensorflow:Saving checkpoints for 10000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 10000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T20:23:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-10000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.59138s
# INFO:tensorflow:Finished evaluation at 2025-10-26-20:30:27
# INFO:tensorflow:Saving dict for global step 10000: global_step = 10000, loss = 0.0015167455, mse = 0.0015167231, rho = 0.9950948
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 10000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-10000
# INFO:tensorflow:global_step/sec: 0.20413
# INFO:tensorflow:loss = 0.0054951194, step = 10000 (489.884 sec)
# INFO:tensorflow:global_step/sec: 1.41519
# INFO:tensorflow:loss = 0.006414062, step = 10100 (70.662 sec)
# INFO:tensorflow:global_step/sec: 1.42363
# INFO:tensorflow:loss = 0.005785313, step = 10200 (70.243 sec)
# INFO:tensorflow:global_step/sec: 1.4205
# INFO:tensorflow:loss = 0.0065583847, step = 10300 (70.397 sec)
# INFO:tensorflow:global_step/sec: 1.41983
# INFO:tensorflow:loss = 0.0060926834, step = 10400 (70.431 sec)
# INFO:tensorflow:global_step/sec: 1.43299
# INFO:tensorflow:loss = 0.006303115, step = 10500 (69.785 sec)
# INFO:tensorflow:global_step/sec: 1.43761
# INFO:tensorflow:loss = 0.0049317298, step = 10600 (69.559 sec)
# INFO:tensorflow:global_step/sec: 1.43378
# INFO:tensorflow:loss = 0.005000745, step = 10700 (69.746 sec)
# INFO:tensorflow:global_step/sec: 1.43222
# INFO:tensorflow:loss = 0.006534652, step = 10800 (69.822 sec)
# INFO:tensorflow:global_step/sec: 1.43479
# INFO:tensorflow:loss = 0.0044679837, step = 10900 (69.696 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 11000...
# INFO:tensorflow:Saving checkpoints for 11000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 11000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T20:42:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-11000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 411.40907s
# INFO:tensorflow:Finished evaluation at 2025-10-26-20:49:05
# INFO:tensorflow:Saving dict for global step 11000: global_step = 11000, loss = 0.00027818556, mse = 0.00027818518, rho = 0.9989631
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 11000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-11000
# INFO:tensorflow:global_step/sec: 0.204904
# INFO:tensorflow:loss = 0.0051013464, step = 11000 (488.033 sec)
# INFO:tensorflow:global_step/sec: 1.43165
# INFO:tensorflow:loss = 0.0054685315, step = 11100 (69.849 sec)
# INFO:tensorflow:global_step/sec: 1.42806
# INFO:tensorflow:loss = 0.005711001, step = 11200 (70.025 sec)
# INFO:tensorflow:global_step/sec: 1.4249
# INFO:tensorflow:loss = 0.0043620253, step = 11300 (70.180 sec)
# INFO:tensorflow:global_step/sec: 1.42471
# INFO:tensorflow:loss = 0.00519293, step = 11400 (70.190 sec)
# INFO:tensorflow:global_step/sec: 1.42965
# INFO:tensorflow:loss = 0.0060347095, step = 11500 (69.947 sec)
# INFO:tensorflow:global_step/sec: 1.4323
# INFO:tensorflow:loss = 0.0052626585, step = 11600 (69.818 sec)
# INFO:tensorflow:global_step/sec: 1.43063
# INFO:tensorflow:loss = 0.0047516557, step = 11700 (69.900 sec)
# INFO:tensorflow:global_step/sec: 1.43851
# INFO:tensorflow:loss = 0.005163714, step = 11800 (69.516 sec)
# INFO:tensorflow:global_step/sec: 1.42977
# INFO:tensorflow:loss = 0.0059733563, step = 11900 (69.941 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 12000...
# INFO:tensorflow:Saving checkpoints for 12000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 12000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T21:00:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-12000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.83603s
# INFO:tensorflow:Finished evaluation at 2025-10-26-21:07:44
# INFO:tensorflow:Saving dict for global step 12000: global_step = 12000, loss = 0.00052436924, mse = 0.0005243717, rho = 0.99885565
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 12000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-12000
# INFO:tensorflow:global_step/sec: 0.204312
# INFO:tensorflow:loss = 0.005381236, step = 12000 (489.448 sec)
# INFO:tensorflow:global_step/sec: 1.40775
# INFO:tensorflow:loss = 0.0044710943, step = 12100 (71.035 sec)
# INFO:tensorflow:global_step/sec: 1.41955
# INFO:tensorflow:loss = 0.005000178, step = 12200 (70.445 sec)
# INFO:tensorflow:global_step/sec: 1.42112
# INFO:tensorflow:loss = 0.005579413, step = 12300 (70.367 sec)
# INFO:tensorflow:global_step/sec: 1.42416
# INFO:tensorflow:loss = 0.0070497952, step = 12400 (70.216 sec)
# INFO:tensorflow:global_step/sec: 1.43589
# INFO:tensorflow:loss = 0.0058993082, step = 12500 (69.644 sec)
# INFO:tensorflow:global_step/sec: 1.43366
# INFO:tensorflow:loss = 0.005477473, step = 12600 (69.751 sec)
# INFO:tensorflow:global_step/sec: 1.43002
# INFO:tensorflow:loss = 0.0042249216, step = 12700 (69.929 sec)
# INFO:tensorflow:global_step/sec: 1.43543
# INFO:tensorflow:loss = 0.005401667, step = 12800 (69.665 sec)
# INFO:tensorflow:global_step/sec: 1.42735
# INFO:tensorflow:loss = 0.006179902, step = 12900 (70.060 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 13000...
# INFO:tensorflow:Saving checkpoints for 13000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 13000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T21:19:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-13000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.47767s
# INFO:tensorflow:Finished evaluation at 2025-10-26-21:26:25
# INFO:tensorflow:Saving dict for global step 13000: global_step = 13000, loss = 0.0002273998, mse = 0.00022739956, rho = 0.9992753
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 13000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-13000
# INFO:tensorflow:global_step/sec: 0.204521
# INFO:tensorflow:loss = 0.0054268357, step = 13000 (488.948 sec)
# INFO:tensorflow:global_step/sec: 1.42585
# INFO:tensorflow:loss = 0.0062069898, step = 13100 (70.134 sec)
# INFO:tensorflow:global_step/sec: 1.4288
# INFO:tensorflow:loss = 0.006408698, step = 13200 (69.989 sec)
# INFO:tensorflow:global_step/sec: 1.42943
# INFO:tensorflow:loss = 0.006047437, step = 13300 (69.958 sec)
# INFO:tensorflow:global_step/sec: 1.43655
# INFO:tensorflow:loss = 0.0048029763, step = 13400 (69.611 sec)
# INFO:tensorflow:global_step/sec: 1.43632
# INFO:tensorflow:loss = 0.0045646736, step = 13500 (69.622 sec)
# INFO:tensorflow:global_step/sec: 1.42139
# INFO:tensorflow:loss = 0.006200772, step = 13600 (70.354 sec)
# INFO:tensorflow:global_step/sec: 1.43877
# INFO:tensorflow:loss = 0.0040426883, step = 13700 (69.504 sec)
# INFO:tensorflow:global_step/sec: 1.43696
# INFO:tensorflow:loss = 0.0045300233, step = 13800 (69.591 sec)
# INFO:tensorflow:global_step/sec: 1.43815
# INFO:tensorflow:loss = 0.004580273, step = 13900 (69.534 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 14000...
# INFO:tensorflow:Saving checkpoints for 14000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 14000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T21:38:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-14000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.29088s
# INFO:tensorflow:Finished evaluation at 2025-10-26-21:45:01
# INFO:tensorflow:Saving dict for global step 14000: global_step = 14000, loss = 0.00028233076, mse = 0.00028233297, rho = 0.99900025
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 14000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-14000
# INFO:tensorflow:global_step/sec: 0.204648
# INFO:tensorflow:loss = 0.005072777, step = 14000 (488.644 sec)
# INFO:tensorflow:global_step/sec: 1.42428
# INFO:tensorflow:loss = 0.0051532006, step = 14100 (70.211 sec)
# INFO:tensorflow:global_step/sec: 1.42179
# INFO:tensorflow:loss = 0.0049012853, step = 14200 (70.334 sec)
# INFO:tensorflow:global_step/sec: 1.42682
# INFO:tensorflow:loss = 0.005395715, step = 14300 (70.086 sec)
# INFO:tensorflow:global_step/sec: 1.42444
# INFO:tensorflow:loss = 0.005414235, step = 14400 (70.203 sec)
# INFO:tensorflow:global_step/sec: 1.42345
# INFO:tensorflow:loss = 0.005349911, step = 14500 (70.252 sec)
# INFO:tensorflow:global_step/sec: 1.42963
# INFO:tensorflow:loss = 0.0049494486, step = 14600 (69.948 sec)
# INFO:tensorflow:global_step/sec: 1.42319
# INFO:tensorflow:loss = 0.0044115647, step = 14700 (70.265 sec)
# INFO:tensorflow:global_step/sec: 1.41519
# INFO:tensorflow:loss = 0.0059452895, step = 14800 (70.662 sec)
# INFO:tensorflow:global_step/sec: 1.40974
# INFO:tensorflow:loss = 0.0064941356, step = 14900 (70.934 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 15000...
# INFO:tensorflow:Saving checkpoints for 15000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 15000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T21:56:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-15000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 411.30488s
# INFO:tensorflow:Finished evaluation at 2025-10-26-22:03:43
# INFO:tensorflow:Saving dict for global step 15000: global_step = 15000, loss = 0.00016557852, mse = 0.00016558045, rho = 0.9991856
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 15000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-15000
# INFO:tensorflow:global_step/sec: 0.204621
# INFO:tensorflow:loss = 0.0057757827, step = 15000 (488.708 sec)
# INFO:tensorflow:global_step/sec: 1.41648
# INFO:tensorflow:loss = 0.005680481, step = 15100 (70.598 sec)
# INFO:tensorflow:global_step/sec: 1.42814
# INFO:tensorflow:loss = 0.005479995, step = 15200 (70.022 sec)
# INFO:tensorflow:global_step/sec: 1.43325
# INFO:tensorflow:loss = 0.005233543, step = 15300 (69.771 sec)
# INFO:tensorflow:global_step/sec: 1.43878
# INFO:tensorflow:loss = 0.0044543534, step = 15400 (69.503 sec)
# INFO:tensorflow:global_step/sec: 1.43435
# INFO:tensorflow:loss = 0.0054264874, step = 15500 (69.718 sec)
# INFO:tensorflow:global_step/sec: 1.43523
# INFO:tensorflow:loss = 0.005022134, step = 15600 (69.675 sec)
# INFO:tensorflow:global_step/sec: 1.4273
# INFO:tensorflow:loss = 0.004471585, step = 15700 (70.063 sec)
# INFO:tensorflow:global_step/sec: 1.43394
# INFO:tensorflow:loss = 0.0051980726, step = 15800 (69.738 sec)
# INFO:tensorflow:global_step/sec: 1.43051
# INFO:tensorflow:loss = 0.005012407, step = 15900 (69.905 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 16000...
# INFO:tensorflow:Saving checkpoints for 16000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 16000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T22:15:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-16000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 410.70581s
# INFO:tensorflow:Finished evaluation at 2025-10-26-22:22:19
# INFO:tensorflow:Saving dict for global step 16000: global_step = 16000, loss = 0.00077226915, mse = 0.0007722688, rho = 0.9978523
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 16000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-16000
# INFO:tensorflow:global_step/sec: 0.205193
# INFO:tensorflow:loss = 0.0062366277, step = 16000 (487.345 sec)
# INFO:tensorflow:global_step/sec: 1.43319
# INFO:tensorflow:loss = 0.004403376, step = 16100 (69.774 sec)
# INFO:tensorflow:global_step/sec: 1.43233
# INFO:tensorflow:loss = 0.005198771, step = 16200 (69.817 sec)
# INFO:tensorflow:global_step/sec: 1.43834
# INFO:tensorflow:loss = 0.0055079646, step = 16300 (69.524 sec)
# INFO:tensorflow:global_step/sec: 1.43277
# INFO:tensorflow:loss = 0.0046279626, step = 16400 (69.858 sec)
# INFO:tensorflow:global_step/sec: 1.4273
# INFO:tensorflow:loss = 0.004189415, step = 16500 (70.000 sec)
# INFO:tensorflow:global_step/sec: 1.43099
# INFO:tensorflow:loss = 0.005009764, step = 16600 (69.881 sec)
# INFO:tensorflow:global_step/sec: 1.43098
# INFO:tensorflow:loss = 0.0046992945, step = 16700 (69.882 sec)
# INFO:tensorflow:global_step/sec: 1.42002
# INFO:tensorflow:loss = 0.0047330535, step = 16800 (70.422 sec)
# INFO:tensorflow:global_step/sec: 1.43052
# INFO:tensorflow:loss = 0.00766911, step = 16900 (69.904 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 17000...
# INFO:tensorflow:Saving checkpoints for 17000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 17000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T22:34:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-17000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 409.51935s
# INFO:tensorflow:Finished evaluation at 2025-10-26-22:40:54
# INFO:tensorflow:Saving dict for global step 17000: global_step = 17000, loss = 0.00019652834, mse = 0.00019653028, rho = 0.9992789
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 17000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-17000
# INFO:tensorflow:global_step/sec: 0.205783
# INFO:tensorflow:loss = 0.0062607783, step = 17000 (485.949 sec)
# INFO:tensorflow:global_step/sec: 1.43054
# INFO:tensorflow:loss = 0.0059434213, step = 17100 (69.904 sec)
# INFO:tensorflow:global_step/sec: 1.4204
# INFO:tensorflow:loss = 0.0071320524, step = 17200 (70.402 sec)
# INFO:tensorflow:global_step/sec: 1.42546
# INFO:tensorflow:loss = 0.0060719633, step = 17300 (70.153 sec)
# INFO:tensorflow:global_step/sec: 1.42755
# INFO:tensorflow:loss = 0.005570824, step = 17400 (70.050 sec)
# INFO:tensorflow:global_step/sec: 1.42971
# INFO:tensorflow:loss = 0.005843578, step = 17500 (69.945 sec)
# INFO:tensorflow:global_step/sec: 1.42994
# INFO:tensorflow:loss = 0.005662239, step = 17600 (69.933 sec)
# INFO:tensorflow:global_step/sec: 1.4342
# INFO:tensorflow:loss = 0.004466536, step = 17700 (69.725 sec)
# INFO:tensorflow:global_step/sec: 1.42486
# INFO:tensorflow:loss = 0.0047647962, step = 17800 (70.182 sec)
# INFO:tensorflow:global_step/sec: 1.42862
# INFO:tensorflow:loss = 0.005980207, step = 17900 (69.998 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 18000...
# INFO:tensorflow:Saving checkpoints for 18000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 18000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T22:52:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-18000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.07201s
# INFO:tensorflow:Finished evaluation at 2025-10-26-22:59:36
# INFO:tensorflow:Saving dict for global step 18000: global_step = 18000, loss = 0.0005078618, mse = 0.0005078676, rho = 0.99854255
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 18000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-18000
# INFO:tensorflow:global_step/sec: 0.203623
# INFO:tensorflow:loss = 0.0049174125, step = 18000 (491.105 sec)
# INFO:tensorflow:global_step/sec: 1.42546
# INFO:tensorflow:loss = 0.005671071, step = 18100 (70.153 sec)
# INFO:tensorflow:global_step/sec: 1.42285
# INFO:tensorflow:loss = 0.0048714615, step = 18200 (70.282 sec)
# INFO:tensorflow:global_step/sec: 1.42244
# INFO:tensorflow:loss = 0.0042089843, step = 18300 (70.301 sec)
# INFO:tensorflow:global_step/sec: 1.43139
# INFO:tensorflow:loss = 0.004459656, step = 18400 (69.862 sec)
# INFO:tensorflow:global_step/sec: 1.43245
# INFO:tensorflow:loss = 0.005089311, step = 18500 (69.810 sec)
# INFO:tensorflow:global_step/sec: 1.43775
# INFO:tensorflow:loss = 0.0046567554, step = 18600 (69.553 sec)
# INFO:tensorflow:global_step/sec: 1.4485
# INFO:tensorflow:loss = 0.0047917916, step = 18700 (69.037 sec)
# INFO:tensorflow:global_step/sec: 1.44158
# INFO:tensorflow:loss = 0.005917048, step = 18800 (69.369 sec)
# INFO:tensorflow:global_step/sec: 1.4313
# INFO:tensorflow:loss = 0.005408065, step = 18900 (69.867 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 19000...
# INFO:tensorflow:Saving checkpoints for 19000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 19000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T23:11:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-19000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 410.76919s
# INFO:tensorflow:Finished evaluation at 2025-10-26-23:18:11
# INFO:tensorflow:Saving dict for global step 19000: global_step = 19000, loss = 0.00016919317, mse = 0.00016919228, rho = 0.99942565
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 19000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-19000
# INFO:tensorflow:global_step/sec: 0.205242
# INFO:tensorflow:loss = 0.0038633742, step = 19000 (487.229 sec)
# INFO:tensorflow:global_step/sec: 1.44684
# INFO:tensorflow:loss = 0.0044967304, step = 19100 (69.117 sec)
# INFO:tensorflow:global_step/sec: 1.42234
# INFO:tensorflow:loss = 0.005844316, step = 19200 (70.306 sec)
# INFO:tensorflow:global_step/sec: 1.42162
# INFO:tensorflow:loss = 0.0068980576, step = 19300 (70.343 sec)
# INFO:tensorflow:global_step/sec: 1.43038
# INFO:tensorflow:loss = 0.0049884534, step = 19400 (69.912 sec)
# INFO:tensorflow:global_step/sec: 1.42309
# INFO:tensorflow:loss = 0.004430956, step = 19500 (70.269 sec)
# INFO:tensorflow:global_step/sec: 1.42622
# INFO:tensorflow:loss = 0.004062327, step = 19600 (70.115 sec)
# INFO:tensorflow:global_step/sec: 1.42379
# INFO:tensorflow:loss = 0.006663901, step = 19700 (70.235 sec)
# INFO:tensorflow:global_step/sec: 1.42773
# INFO:tensorflow:loss = 0.0044093365, step = 19800 (70.041 sec)
# INFO:tensorflow:global_step/sec: 1.43457
# INFO:tensorflow:loss = 0.0055379365, step = 19900 (69.708 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 20000...
# INFO:tensorflow:Saving checkpoints for 20000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 20000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T23:29:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 411.03006s
# INFO:tensorflow:Finished evaluation at 2025-10-26-23:36:49
# INFO:tensorflow:Saving dict for global step 20000: global_step = 20000, loss = 0.00017030137, mse = 0.0001702994, rho = 0.9992478
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-20000
# INFO:tensorflow:global_step/sec: 0.205162
# INFO:tensorflow:loss = 0.0045035505, step = 20000 (487.419 sec)
# INFO:tensorflow:global_step/sec: 1.44613
# INFO:tensorflow:loss = 0.0052630217, step = 20100 (69.151 sec)
# INFO:tensorflow:global_step/sec: 1.42482
# INFO:tensorflow:loss = 0.005819272, step = 20200 (70.184 sec)
# INFO:tensorflow:global_step/sec: 1.4294
# INFO:tensorflow:loss = 0.0063424264, step = 20300 (69.960 sec)
# INFO:tensorflow:global_step/sec: 1.42992
# INFO:tensorflow:loss = 0.0057776584, step = 20400 (69.934 sec)
# INFO:tensorflow:global_step/sec: 1.43174
# INFO:tensorflow:loss = 0.007288647, step = 20500 (69.845 sec)
# INFO:tensorflow:global_step/sec: 1.43481
# INFO:tensorflow:loss = 0.004246028, step = 20600 (69.696 sec)
# INFO:tensorflow:global_step/sec: 1.44056
# INFO:tensorflow:loss = 0.00555217, step = 20700 (69.418 sec)
# INFO:tensorflow:global_step/sec: 1.43913
# INFO:tensorflow:loss = 0.0052644024, step = 20800 (69.486 sec)
# INFO:tensorflow:global_step/sec: 1.4285
# INFO:tensorflow:loss = 0.006477748, step = 20900 (70.004 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 21000...
# INFO:tensorflow:Saving checkpoints for 21000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 21000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-26T23:48:33
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-21000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 410.47167s
# INFO:tensorflow:Finished evaluation at 2025-10-26-23:55:23
# INFO:tensorflow:Saving dict for global step 21000: global_step = 21000, loss = 0.0004982128, mse = 0.0004982143, rho = 0.9987298
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 21000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-21000
# ...
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 43000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-27T06:37:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-43000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 410.70859s
# INFO:tensorflow:Finished evaluation at 2025-10-27-06:44:46
# INFO:tensorflow:Saving dict for global step 43000: global_step = 43000, loss = 0.00031486558, mse = 0.00031486902, rho = 0.9994658
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 43000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-43000
# INFO:tensorflow:global_step/sec: 0.205126
# INFO:tensorflow:loss = 0.0058282022, step = 43000 (487.505 sec)
# INFO:tensorflow:global_step/sec: 1.42285
# INFO:tensorflow:loss = 0.004558621, step = 43100 (70.282 sec)
# INFO:tensorflow:global_step/sec: 1.42013
# INFO:tensorflow:loss = 0.004850421, step = 43200 (70.417 sec)
# INFO:tensorflow:global_step/sec: 1.41661
# INFO:tensorflow:loss = 0.0050160526, step = 43300 (70.591 sec)
# INFO:tensorflow:global_step/sec: 1.41884
# INFO:tensorflow:loss = 0.0046611046, step = 43400 (70.480 sec)
# INFO:tensorflow:global_step/sec: 1.42172
# INFO:tensorflow:loss = 0.0057405904, step = 43500 (70.337 sec)
# INFO:tensorflow:global_step/sec: 1.41458
# INFO:tensorflow:loss = 0.006426942, step = 43600 (70.692 sec)
# INFO:tensorflow:global_step/sec: 1.41322
# INFO:tensorflow:loss = 0.004669071, step = 43700 (70.761 sec)
# INFO:tensorflow:global_step/sec: 1.43565
# INFO:tensorflow:loss = 0.00413844, step = 43800 (69.654 sec)
# INFO:tensorflow:global_step/sec: 1.43223
# INFO:tensorflow:loss = 0.00546986, step = 43900 (69.821 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 44000...
# INFO:tensorflow:Saving checkpoints for 44000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 44000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-27T06:56:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-44000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 411.48175s
# INFO:tensorflow:Finished evaluation at 2025-10-27-07:03:27
# INFO:tensorflow:Saving dict for global step 44000: global_step = 44000, loss = 0.00023317238, mse = 0.00023317174, rho = 0.9995739
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 44000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-44000
# INFO:tensorflow:global_step/sec: 0.204817
# INFO:tensorflow:loss = 0.0049815746, step = 44000 (488.241 sec)
# INFO:tensorflow:global_step/sec: 1.41547
# INFO:tensorflow:loss = 0.0046213036, step = 44100 (70.648 sec)
# INFO:tensorflow:global_step/sec: 1.4134
# INFO:tensorflow:loss = 0.0043827007, step = 44200 (70.751 sec)
# INFO:tensorflow:global_step/sec: 1.423
# INFO:tensorflow:loss = 0.0041493885, step = 44300 (70.275 sec)
# INFO:tensorflow:global_step/sec: 1.42188
# INFO:tensorflow:loss = 0.005605913, step = 44400 (70.329 sec)
# INFO:tensorflow:global_step/sec: 1.41881
# INFO:tensorflow:loss = 0.005373709, step = 44500 (70.482 sec)
# INFO:tensorflow:global_step/sec: 1.4238
# INFO:tensorflow:loss = 0.004938654, step = 44600 (70.235 sec)
# INFO:tensorflow:global_step/sec: 1.42375
# INFO:tensorflow:loss = 0.006655925, step = 44700 (70.237 sec)
# INFO:tensorflow:global_step/sec: 1.42543
# INFO:tensorflow:loss = 0.007095159, step = 44800 (70.154 sec)
# INFO:tensorflow:global_step/sec: 1.41628
# INFO:tensorflow:loss = 0.0052174996, step = 44900 (70.607 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 45000...
# INFO:tensorflow:Saving checkpoints for 45000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 45000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-27T07:15:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-45000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 410.11577s
# INFO:tensorflow:Finished evaluation at 2025-10-27-07:22:08
# INFO:tensorflow:Saving dict for global step 45000: global_step = 45000, loss = 0.00011279184, mse = 0.00011279227, rho = 0.999646
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 45000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-45000
# INFO:tensorflow:global_step/sec: 0.205232
# INFO:tensorflow:loss = 0.005467371, step = 45000 (487.254 sec)
# INFO:tensorflow:global_step/sec: 1.42658
# INFO:tensorflow:loss = 0.004786997, step = 45100 (70.098 sec)
# INFO:tensorflow:global_step/sec: 1.43049
# INFO:tensorflow:loss = 0.004129312, step = 45200 (69.907 sec)
# INFO:tensorflow:global_step/sec: 1.43809
# INFO:tensorflow:loss = 0.004478448, step = 45300 (69.537 sec)
# INFO:tensorflow:global_step/sec: 1.43854
# INFO:tensorflow:loss = 0.0047457335, step = 45400 (69.515 sec)
# INFO:tensorflow:global_step/sec: 1.43387
# INFO:tensorflow:loss = 0.0059840186, step = 45500 (69.741 sec)
# INFO:tensorflow:global_step/sec: 1.43634
# INFO:tensorflow:loss = 0.004045531, step = 45600 (69.622 sec)
# INFO:tensorflow:global_step/sec: 1.43597
# INFO:tensorflow:loss = 0.0053743757, step = 45700 (69.639 sec)
# INFO:tensorflow:global_step/sec: 1.43658
# INFO:tensorflow:loss = 0.004339938, step = 45800 (69.610 sec)
# INFO:tensorflow:global_step/sec: 1.42978
# INFO:tensorflow:loss = 0.005786626, step = 45900 (69.940 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 46000...
# INFO:tensorflow:Saving checkpoints for 46000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 46000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-27T07:33:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-46000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 410.34193s
# INFO:tensorflow:Finished evaluation at 2025-10-27-07:40:43
# INFO:tensorflow:Saving dict for global step 46000: global_step = 46000, loss = 0.0003361003, mse = 0.00033610218, rho = 0.9991057
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-46000
# INFO:tensorflow:global_step/sec: 0.205183
# INFO:tensorflow:loss = 0.0045471378, step = 46000 (487.369 sec)
# INFO:tensorflow:global_step/sec: 1.41683
# INFO:tensorflow:loss = 0.0047612647, step = 46100 (70.580 sec)
# INFO:tensorflow:global_step/sec: 1.42533
# INFO:tensorflow:loss = 0.0053580543, step = 46200 (70.159 sec)
# INFO:tensorflow:global_step/sec: 1.43068
# INFO:tensorflow:loss = 0.004402378, step = 46300 (69.897 sec)
# INFO:tensorflow:global_step/sec: 1.42951
# INFO:tensorflow:loss = 0.005268066, step = 46400 (69.954 sec)
# INFO:tensorflow:global_step/sec: 1.4337
# INFO:tensorflow:loss = 0.004572547, step = 46500 (69.750 sec)
# INFO:tensorflow:global_step/sec: 1.43063
# INFO:tensorflow:loss = 0.005070458, step = 46600 (69.899 sec)
# INFO:tensorflow:global_step/sec: 1.42384
# INFO:tensorflow:loss = 0.00467225, step = 46700 (70.233 sec)
# INFO:tensorflow:global_step/sec: 1.43455
# INFO:tensorflow:loss = 0.005302091, step = 46800 (69.708 sec)
# INFO:tensorflow:global_step/sec: 1.43006
# INFO:tensorflow:loss = 0.0055915974, step = 46900 (69.927 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 47000...
# INFO:tensorflow:Saving checkpoints for 47000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 47000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-27T07:52:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-47000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 410.73653s
# INFO:tensorflow:Finished evaluation at 2025-10-27-07:59:21
# INFO:tensorflow:Saving dict for global step 47000: global_step = 47000, loss = 0.00021802072, mse = 0.00021802081, rho = 0.99914646
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 47000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-47000
# INFO:tensorflow:global_step/sec: 0.204996
# INFO:tensorflow:loss = 0.0057964474, step = 47000 (487.813 sec)
# INFO:tensorflow:global_step/sec: 1.4199
# INFO:tensorflow:loss = 0.004965827, step = 47100 (70.428 sec)
# INFO:tensorflow:global_step/sec: 1.4197
# INFO:tensorflow:loss = 0.004649629, step = 47200 (70.438 sec)
# INFO:tensorflow:global_step/sec: 1.43147
# INFO:tensorflow:loss = 0.0055528376, step = 47300 (69.858 sec)
# INFO:tensorflow:global_step/sec: 1.42982
# INFO:tensorflow:loss = 0.0047372775, step = 47400 (69.939 sec)
# INFO:tensorflow:global_step/sec: 1.4292
# INFO:tensorflow:loss = 0.004730721, step = 47500 (69.970 sec)
# INFO:tensorflow:global_step/sec: 1.43533
# INFO:tensorflow:loss = 0.0047493614, step = 47600 (69.670 sec)
# INFO:tensorflow:global_step/sec: 1.43488
# INFO:tensorflow:loss = 0.006631773, step = 47700 (69.757 sec)
# INFO:tensorflow:global_step/sec: 1.42261
# INFO:tensorflow:loss = 0.004882227, step = 47800 (70.229 sec)
# INFO:tensorflow:global_step/sec: 1.42385
# INFO:tensorflow:loss = 0.004719708, step = 47900 (70.233 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 48000...
# INFO:tensorflow:Saving checkpoints for 48000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 48000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-27T08:11:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-48000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 412.91396s
# INFO:tensorflow:Finished evaluation at 2025-10-27-08:18:04
# INFO:tensorflow:Saving dict for global step 48000: global_step = 48000, loss = 0.00035874257, mse = 0.00035874586, rho = 0.9991864
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 48000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-48000
# INFO:tensorflow:global_step/sec: 0.202739
# INFO:tensorflow:loss = 0.004353741, step = 48000 (493.244 sec)
# INFO:tensorflow:global_step/sec: 1.4155
# INFO:tensorflow:loss = 0.0056844004, step = 48100 (70.647 sec)
# INFO:tensorflow:global_step/sec: 1.4132
# INFO:tensorflow:loss = 0.0048732087, step = 48200 (70.761 sec)
# INFO:tensorflow:global_step/sec: 1.43426
# INFO:tensorflow:loss = 0.005107957, step = 48300 (69.723 sec)
# INFO:tensorflow:global_step/sec: 1.42463
# INFO:tensorflow:loss = 0.0052942866, step = 48400 (70.193 sec)
# INFO:tensorflow:global_step/sec: 1.42649
# INFO:tensorflow:loss = 0.0044992315, step = 48500 (70.103 sec)
# INFO:tensorflow:global_step/sec: 1.42296
# INFO:tensorflow:loss = 0.005027796, step = 48600 (70.276 sec)
# INFO:tensorflow:global_step/sec: 1.42978
# INFO:tensorflow:loss = 0.0040996615, step = 48700 (69.941 sec)
# INFO:tensorflow:global_step/sec: 1.43069
# INFO:tensorflow:loss = 0.004249135, step = 48800 (69.896 sec)
# INFO:tensorflow:global_step/sec: 1.4379
# INFO:tensorflow:loss = 0.0053533083, step = 48900 (69.546 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 49000...
# INFO:tensorflow:Saving checkpoints for 49000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 49000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-27T08:29:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-49000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 411.19634s
# INFO:tensorflow:Finished evaluation at 2025-10-27-08:36:43
# INFO:tensorflow:Saving dict for global step 49000: global_step = 49000, loss = 0.00027102823, mse = 0.00027102872, rho = 0.99931073
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 49000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-49000
# INFO:tensorflow:global_step/sec: 0.205063
# INFO:tensorflow:loss = 0.0043439055, step = 49000 (487.655 sec)
# INFO:tensorflow:global_step/sec: 1.44002
# INFO:tensorflow:loss = 0.0056540444, step = 49100 (69.443 sec)
# INFO:tensorflow:global_step/sec: 1.43159
# INFO:tensorflow:loss = 0.0049274373, step = 49200 (69.853 sec)
# INFO:tensorflow:global_step/sec: 1.43079
# INFO:tensorflow:loss = 0.0059232996, step = 49300 (69.892 sec)
# INFO:tensorflow:global_step/sec: 1.42755
# INFO:tensorflow:loss = 0.0050308425, step = 49400 (70.050 sec)
# INFO:tensorflow:global_step/sec: 1.42873
# INFO:tensorflow:loss = 0.006426021, step = 49500 (69.992 sec)
# INFO:tensorflow:global_step/sec: 1.41218
# INFO:tensorflow:loss = 0.0052780565, step = 49600 (70.813 sec)
# INFO:tensorflow:global_step/sec: 1.41464
# INFO:tensorflow:loss = 0.0059850197, step = 49700 (70.689 sec)
# INFO:tensorflow:global_step/sec: 1.42341
# INFO:tensorflow:loss = 0.005714123, step = 49800 (70.254 sec)
# INFO:tensorflow:global_step/sec: 1.42196
# INFO:tensorflow:loss = 0.0050787004, step = 49900 (70.325 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 50000...
# INFO:tensorflow:Saving checkpoints for 50000 into rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 50000...
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2025-10-27T08:48:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-50000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Inference Time : 411.82185s
# INFO:tensorflow:Finished evaluation at 2025-10-27-08:55:23
# INFO:tensorflow:Saving dict for global step 50000: global_step = 50000, loss = 8.9838184e-05, mse = 8.983849e-05, rho = 0.99967456
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50000: rn0_models_distributed_bs32_lamb_l2-01_gbn_parse_74_70/model.ckpt-50000
# INFO:tensorflow:Loss for final step: 0.006474712.
# CPU times: user 4d 3h 9min 34s, sys: 21h 56min 54s, total: 5d 1h 6min 28s
# Wall time: 15h 35min 13s
